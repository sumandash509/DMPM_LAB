# %% [markdown]
# <a href="https://colab.research.google.com/github/sumandash509/DMPM_LAB/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter the 1st number: "))
b = int(input("Enter the 2nd number: "))
c = int(input("Enter the 3rd number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("The largest number is", largest)
# Out:
# Enter the 1st number: 3
# Enter the 2nd number: 5
# Enter the 3rd number: 8
# The largest number is 8

# %%
a=int(input("enter the even number"))
b=int(input("enter the odd number"))

if a%2==0:
    print("even")
else:
    print("odd")

if b%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter the even number67
# enter the odd number88
# odd
# even

# %%
a=(input("enter the string"))
if a==a[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# enter the string55
# palindrome

# %%
num = int(input("Enter a number: "))

is_prime = True
if num <= 1:
    is_prime = False
else:
    for i in range(2, int(num**0.5) + 1):
        if (num % i) == 0:
            is_prime = False
            break

if is_prime:
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number: 44
# 44 is not a prime number.

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

print("Before swapping: a =", a, ", b =", b)

a = a + b
b = a - b
a = a - b

print("After swapping: a =", a, ", b =", b)
# Out:
# Enter the first number: 44
# Enter the second number: 52
# Before swapping: a = 44 , b = 52
# After swapping: a = 52 , b = 44

# %%
string =input("enter the string")
vowels = "aeiouAEIOU"
count = 0
for char in string:
    if char in vowels:
        count += 1
print("Number of vowels in the string:", count)
# Out:
# enter the string56
# Number of vowels in the string: 0

# %%
num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if operator == '+':
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator == '-':
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator == '*':
    result = num1 * num2
    print(f"{num1} * {num2} = {result}")
elif operator == '/':
    if num2 != 0:
        result = num1 / num2
        print(f"{num1} / {num2} = {result}")
else:
    print("Invalid operator.")
# Out:
# Enter first number: 54
# Enter operator (+, -, *, /): +
# Enter second number: 65
# 54.0 + 65.0 = 119.0

# %%
a = int(input("Enter the number: "))
original_number = a
reverse = 0
while a > 0:
    digit = a % 10
    reverse = reverse * 10 + digit
    a //= 10
print("The reversed number is:", reverse)
# Out:
# Enter the number: 44
# The reversed number is: 44

# %%
n = int(input("Enter a number: "))

sum = 0

while n > 0:
    digit = n % 10
    sum += digit
    n = n // 10

print("Sum of digits is:", sum)
# Out:
# Enter a number: 54
# Sum of digits is: 9

# %%
num = int(input("Enter an integer: "))

if num < 0:
    print("Factorial is not defined for negative numbers.")
elif num == 0:
    print("The factorial of 0 is 1.")
else:
    factorial = 1
    for i in range(1, num + 1):
        factorial *= i
    print(f"The factorial of {num} is {factorial}.")
# Out:
# Enter an integer: 54
# The factorial of 54 is 230843697339241380472092742683027581083278564571807941132288000000000000.
